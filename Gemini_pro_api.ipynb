# %% [markdown]
# <a href="https://colab.research.google.com/github/amit6895/gemini-pro-api/blob/main/Gemini_pro_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install -q -U google-generativeai
 # !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 794.4/794.4 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.4/192.4 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## import package

# %%
import pathlib
import textwrap
import google.generativeai as genai

from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  # text = text.replace('.' , '  ')
  return Markdown(textwrap.indent(text , '> ', predicate=lambda _:True))

# %%
my_key = "AIzaSyDgqAZvodRYDERTgqEInO_ChP7h5853hu8"

# %%
import os
os.environ["GOOGLE_API_KEY"] = my_key

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel("gemini-pro")

# %%
# %%time
response = model.generate_content("what is life?")
# Out:
# CPU times: user 117 ms, sys: 16.2 ms, total: 134 ms
# Wall time: 9.72 s

# %%
type(response)
# Out:
# google.generativeai.types.generation_types.GenerateContentResponse

# %%
print(response.text)
# Out:
# Life is a complex and multifaceted phenomenon that has been the subject of philosophical, scientific, and religious inquiry for centuries. There is no single, universally accepted definition of life, but it is generally understood to be the state of being alive, or the set of processes that constitute the existence of a living organism.
#
# One common understanding of life is that it is a self-sustaining chemical system capable of reproducing itself. Living organisms are composed of cells, which contain DNA and other molecules that encode the instructions for the organism to grow, reproduce, and respond to its environment. Living organisms also have a metabolism, which is the process by which they acquire and use energy to maintain their structure and function.
#
# ...

# %%
to_markdown(response.text)
# Out:
# > Life is a complex and multifaceted phenomenon that has been the subject of philosophical, scientific, and religious inquiry for centuries. There is no single, universally accepted definition of life, but it is generally understood to be the state of being alive, or the set of processes that constitute the existence of a living organism.
# >
# > One common understanding of life is that it is a self-sustaining chemical system capable of reproducing itself. Living organisms are composed of cells, which contain DNA and other molecules that encode the instructions for the organism to grow, reproduce, and respond to its environment. Living organisms also have a metabolism, which is the process by which they acquire and use energy to maintain their structure and function.
# >
# ...

# %%
response.prompt_feedback
# Out:
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }

# %%
# !pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
import PIL.Image
img = PIL.Image.open("/content/WhatsApp Image 2023-11-05 at 12.00.58 PM.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x427>

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(["explain the problem and give the solution" , img] )

# %%
to_markdown(response.text)
# Out:
# >  The balls are falling randomly, so the probability of a blue ball falling first is 10/19. The probability of a red ball falling first is 6/19. The probability of a green ball falling first is 3/19.
# >
# > If a blue ball falls first, the expected number of seconds before you see the first blue ball falling is 0 seconds.
# >
# > If a red ball falls first, the expected number of seconds before you see the first blue ball falling is 1 second.
# >
# > If a green ball falls first, the expected number of seconds before you see the first blue ball falling is 2 seconds.
# >
# > Therefore, the expected number of seconds before you see the first blue ball falling is:
# >
# > (10/19) * 0 + (6/19) * 1 + (3/19) * 2 = 1.81 seconds.
# >
# > The answer is 1.81.

# %%
print(response.text)
# Out:
#  The balls are falling randomly, so the probability of a blue ball falling first is 10/19. The probability of a red ball falling first is 6/19. The probability of a green ball falling first is 3/19.
#
# If a blue ball falls first, the expected number of seconds before you see the first blue ball falling is 0 seconds.
#
# If a red ball falls first, the expected number of seconds before you see the first blue ball falling is 1 second.
#
# If a green ball falls first, the expected number of seconds before you see the first blue ball falling is 2 seconds.
#
# Therefore, the expected number of seconds before you see the first blue ball falling is:
#
# (10/19) * 0 + (6/19) * 1 + (3/19) * 2 = 1.81 seconds.
#
# The answer is 1.81.
